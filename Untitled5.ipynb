# %%
import random
b=[]
for i in range(5000):
    a=random.randint(1,6)
    b.append(a)
print(b)
# Out:
# [2, 1, 4, 5, 4, 3, 3, 5, 3, 4, 4, 4, 2, 6, 2, 4, 5, 1, 3, 1, 4, 1, 5, 1, 6, 1, 1, 2, 1, 1, 5, 5, 4, 6, 4, 4, 5, 5, 3, 3, 6, 2, 4, 4, 5, 4, 5, 2, 2, 1, 3, 4, 2, 6, 4, 5, 2, 4, 3, 4, 4, 1, 4, 5, 1, 5, 1, 6, 4, 3, 6, 2, 5, 6, 2, 1, 1, 6, 6, 5, 6, 2, 2, 3, 1, 2, 5, 1, 2, 1, 6, 5, 2, 5, 4, 2, 1, 2, 2, 4, 1, 6, 2, 5, 6, 5, 5, 1, 3, 4, 4, 3, 5, 2, 3, 2, 5, 6, 5, 3, 4, 6, 6, 3, 1, 6, 2, 5, 6, 6, 4, 6, 5, 5, 2, 6, 3, 5, 6, 4, 6, 2, 1, 4, 1, 5, 2, 5, 6, 2, 5, 3, 5, 3, 3, 2, 5, 1, 6, 4, 3, 3, 4, 5, 3, 3, 6, 4, 5, 3, 4, 4, 2, 5, 6, 5, 3, 3, 5, 3, 2, 3, 2, 2, 6, 5, 4, 6, 3, 5, 4, 6, 1, 6, 5, 1, 1, 6, 1, 6, 6, 2, 6, 5, 3, 5, 6, 5, 5, 3, 1, 5, 5, 1, 5, 4, 5, 4, 4, 6, 5, 1, 4, 4, 1, 5, 2, 2, 1, 1, 5, 5, 4, 3, 5, 4, 2, 1, 5, 3, 2, 4, 5, 4, 2, 4, 6, 6, 4, 1, 3, 4, 4, 5, 3, 6, 5, 2, 6, 5, 2, 6, 5, 3, 1, 3, 2, 4, 4, 4, 6, 2, 6, 2, 4, 1, 5, 2, 6, 1, 5, 6, 5, 6, 5, 1, 4, 4, 6, 6, 3, 3, 2, 6, 6, 3, 4, 1, 5, 3, 3, 4, 5, 3, 3, 5, 5, 6, 2, 5, 2, 1, 2, 5, 5, 3, 3, 2, 6, 6, 6, 2, 4, 2, 3, 3, 6, 4, 1, 3, 6, 6, 3
# ...

# %%
s1=[]
s2=[]
s3=[]
s4=[]
s5=[]
s6=[]
for i in range(4999):
    if(b[i]==1):
            s1.append(b[i+1])
            
    elif (b[i]==2):
        s2.append(b[i+1])
        
    elif (b[i]==3):
        s3.append(b[i+1])

    elif (b[i]==4):
        s4.append(b[i+1])
        
    elif (b[i]==5):
        s5.append(b[i+1])
    
    elif (b[i]==6):
        s6.append(b[i+1])
print('print sample space for 1', s1)
#print("Sample space for 2:",s2)
#print("Sample space for 3:",s3)
#print("Sample space for 4:",s4)
#print("Sample space for 5:",s5)
#print("Sample space for 6:",s6)
# Out:
# print sample space for 1 [4, 3, 4, 5, 6, 1, 2, 1, 5, 3, 4, 5, 6, 1, 6, 2, 2, 6, 2, 6, 3, 6, 4, 5, 6, 6, 1, 6, 6, 5, 5, 4, 5, 1, 5, 5, 3, 3, 5, 5, 4, 5, 2, 3, 1, 2, 6, 1, 4, 1, 5, 3, 1, 3, 2, 6, 2, 5, 6, 6, 5, 6, 4, 4, 4, 4, 1, 1, 2, 3, 5, 6, 4, 6, 1, 5, 6, 5, 1, 5, 5, 2, 2, 5, 1, 3, 4, 1, 1, 2, 4, 6, 4, 3, 3, 6, 1, 3, 2, 2, 1, 2, 5, 5, 3, 2, 2, 3, 5, 5, 3, 5, 1, 5, 6, 6, 2, 5, 3, 1, 4, 3, 6, 5, 3, 1, 6, 4, 1, 3, 2, 2, 2, 6, 4, 3, 2, 4, 6, 2, 3, 2, 4, 3, 3, 2, 2, 3, 6, 1, 1, 6, 4, 6, 3, 2, 5, 4, 2, 1, 5, 5, 4, 3, 4, 5, 6, 3, 1, 1, 6, 5, 4, 2, 5, 1, 6, 5, 3, 5, 2, 6, 2, 2, 2, 6, 2, 5, 3, 5, 2, 2, 5, 3, 2, 1, 1, 6, 5, 1, 2, 4, 5, 4, 1, 2, 3, 2, 6, 4, 2, 1, 1, 5, 5, 1, 6, 3, 3, 5, 1, 1, 6, 1, 5, 4, 4, 6, 3, 3, 2, 5, 1, 2, 5, 2, 2, 4, 2, 1, 4, 5, 6, 6, 3, 2, 3, 2, 6, 1, 5, 6, 5, 4, 1, 2, 3, 5, 4, 6, 6, 2, 1, 3, 5, 3, 4, 3, 1, 6, 4, 3, 4, 1, 2, 6, 2, 4, 1, 3, 3, 4, 5, 5, 6, 2, 5, 2, 3, 4, 4, 4, 3, 3, 4, 1, 4, 1, 2, 6, 4, 6, 2, 6, 4, 4, 1, 6, 3, 3, 5, 6, 4, 4, 2, 1, 1, 2, 4, 3, 1, 5, 1, 2, 
# ...

# %%
from collections import Counter
c1=Counter(s1)
c2=Counter(s2)
c3=Counter(s3)
c4=Counter(s4)
c5=Counter(s5)
c6=Counter(s6)
print (c1)
print(c1.items())
p1=c1.values()
print(p1)
q1=sum(p1)
print(q1)
print(c2.items())
p2=c2.values()
print(p2)
q2=sum(p2)
print(q2)
print(c3.items())
p3=c3.values()
print(p3)
q3=sum(p3)
print(q3)
print(c4.items())
p4=c4.values()
print(p4)
q4=sum(p4)
print(q4)
print(c5.items())
p5=c5.values()
print(p5)
q5=sum(p5)
print(q5)
print(c6.items())
p6=c6.values()
print(p6)
q6=sum(p6)
print(q6)

def prob(dict,q):
    for i in dict:
        dict[i]=float(dict[i]/q)
    print(dict)
    return dict

x1=prob(c1,q1)

x2=prob(c2,q2)
x3=prob(c3,q3)
x4=prob(c4,q4)
x5=prob(c5,q5)
x6=prob(c6,q6)
# Out:
# Counter({2: 150, 6: 140, 1: 139, 3: 137, 5: 136, 4: 131})
# dict_items([(4, 131), (3, 137), (5, 136), (6, 140), (1, 139), (2, 150)])
# dict_values([131, 137, 136, 140, 139, 150])
# 833
# dict_items([(1, 140), (6, 128), (4, 139), (2, 150), (5, 147), (3, 136)])
# dict_values([140, 128, 139, 150, 147, 136])
# 840
# dict_items([(3, 155), (5, 148), (4, 122), (1, 148), (6, 135), (2, 128)])
# dict_values([155, 148, 122, 148, 135, 128])
# 836
# dict_items([(5, 141), (3, 109), (4, 137), (2, 128), (1, 130), (6, 152)])
# dict_values([141, 109, 137, 128, 130, 152])
# 797
# dict_items([(4, 152), (3, 153), (1, 143), (5, 147), (2, 131), (6, 132)])
# dict_values([152, 153, 143, 147, 131, 132])
# 858
# dict_items([(2, 152), (1, 133), (4, 116), (6, 148), (5, 139), (3, 147)])
# dict_values([152, 133, 116, 148, 139, 147])
# 835
# Counter({2: 0.18007202881152462, 6: 0.16806722689075632, 1: 0.16686674669867949, 3: 0.1644657863145258, 5: 0.16326530612244897, 4: 0.15726290516206481})
# ...

# %%
import re
from nltk.util import ngrams
file=open(r"C:\Users\Avinash\Downloads\lab.csv",'r',encoding="utf8")

print((r))
#file=file.lower()
file= re.sub(r'[^a-zA-Z0-9\s]', ' ', file)
tokens = [token for token in file.split(" ") if token != " "]
output = list(ngrams(tokens, 4))
# Out:
# <_io.TextIOWrapper name='C:\\Users\\Avinash\\Downloads\\lab.csv' mode='r' encoding='utf8'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-3eac0376c844> in <module>
#       5 print((r))
#       6 #file=file.lower()
# ----> 7 file= re.sub(r'[^a-zA-Z0-9\s]', ' ', file)
#       8 tokens = [token for token in file.split(" ") if token != " "]
#       9 output = list(ngrams(tokens, 4))
#
# c:\users\avinash\appdata\local\programs\python\python36\lib\re.py in sub(pattern, repl, string, count, flags)
#     189     a callable, it's passed the match object and must return
#     190     a replacement string to be used."""
# --> 191     return _compile(pattern, flags).sub(repl, string, count)
#     192
#     193 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
file=open(r"C:\Users\Avinash\Downloads\lab.csv",'r',encoding="utf8")
for i in range(30):
      text = file.readline()
print(text)
# Out:
# "Yes, powershell's got the same problem.",,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,

# %%
def process_text(text):
 
    text = text.lower()
    text = text.replace(',', ' ')
    text = text.replace('/', ' ')
    text = text.replace('(', ' ')
    text = text.replace(')', ' ')
    text = text.replace('.', ' ')
 
    # Convert text string to a list of words
    return text.split()
def generate_ngrams(words_list, n):
    ngrams_list = []
 
    for num in range(0, len(words_list)):
        ngram = ' '.join(words_list[num:num + n])
        ngrams_list.append(ngram)
 
    return ngrams_list
if __name__ == "__main__":
 
    #text = open(r"C:\Users\Avinash\Downloads\lab.csv",'r',encoding="utf8")
    
    words_list = process_text(text)
   # unigrams = generate_ngrams(words_list, 1)
    bigrams = generate_ngrams(words_list, 2)
    trigrams = generate_ngrams(words_list, 3)
    fourgrams = generate_ngrams(words_list, 4)
   # fivegrams = generate_ngrams(words_list, 5)
 
    print ( bigrams + trigrams + fourgrams)
# Out:
# ['"yes powershell\'s', "powershell's got", 'got the', 'the same', 'same problem', 'problem "', '"', '"yes powershell\'s got', "powershell's got the", 'got the same', 'the same problem', 'same problem "', 'problem "', '"', '"yes powershell\'s got the', "powershell's got the same", 'got the same problem', 'the same problem "', 'same problem "', 'problem "', '"']
